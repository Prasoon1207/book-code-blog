# %% [markdown]
# # Example Chapter: Introduction to Data Analysis
#
# **Book**: *Python for Data Analysis* by Wes McKinney
# **Chapter**: 1 - Preliminaries
#
# ---
#
# This notebook demonstrates basic data analysis concepts using Python. Replace this with your own content from any book you're studying.

# %% [markdown]
# ## Setup
#
# First, let's import the necessary libraries:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set style for better-looking plots
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)

# %% [markdown]
# ## Creating Sample Data
#
# Let's create a simple dataset to work with:

# %%
# Generate sample data
np.random.seed(42)
dates = pd.date_range('2024-01-01', periods=100)
data = {
    'date': dates,
    'value': np.random.randn(100).cumsum(),
    'category': np.random.choice(['A', 'B', 'C'], 100)
}

df = pd.DataFrame(data)
df.head(10)

# %% [markdown]
# ## Basic Analysis
#
# Let's perform some basic exploratory data analysis:

# %%
# Summary statistics
print("Summary Statistics:")
print(df.describe())
print("\nValue counts by category:")
print(df['category'].value_counts())

# %% [markdown]
# ## Visualization
#
# Visualize the data to identify patterns:

# %%
# Time series plot
plt.figure(figsize=(12, 6))
plt.plot(df['date'], df['value'], linewidth=2)
plt.title('Time Series of Values', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Value', fontsize=12)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Box plot by category
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='category', y='value', palette='Set2')
plt.title('Distribution of Values by Category', fontsize=16)
plt.xlabel('Category', fontsize=12)
plt.ylabel('Value', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Key Takeaways
#
# - **Concept 1**: Explain the main concept from this chapter
# - **Concept 2**: Highlight important patterns or insights
# - **Concept 3**: Note any best practices or common pitfalls
#
# ## Next Steps
#
# Continue to the next chapter to explore [Next Topic].

# %% [markdown]
# ---
#
# **References**:
# - Book Title and Author
# - Chapter Number and Title
# - Any additional resources or links
